# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalisha1234/My-Projects/blob/main/Try0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/similarweb.csv')

# %%
data
# Out:
#            name             site  global_rank  country_rank  category_rank  \
# 0        Adidas       adidas.com         1464           371             11
# 1         ASICS        asics.com         3505          1892             44
# 2      Columbia     columbia.com         9122          1918             93
# 3          Fila         fila.com        65229         16405            558
# 4       K-Swiss       kswiss.com       168994         32037           1020
# 5   New Balance   newbalance.com         5241          1165             62
# 6          Nike         nike.com          231           126              4
# 7          Puma         puma.com         1697          1851             92
# 8      Skechers     skechers.com         3246           650             26
# 9  Under Armour  underarmour.com         4976          1132             58
#
#   total_visits  bounce_rate  pages_per_visit avg_visit_duration  \
# 0        31.5M        49.84             4.85           00:03:01
# ...

# %%
data.isnull().sum()
# Out:
# name                        0
# site                        0
# global_rank                 0
# country_rank                0
# category_rank               0
# total_visits                0
# bounce_rate                 0
# pages_per_visit             0
# avg_visit_duration          0
# country1_name               0
# country1_percent            0
# country2_name               0
# country2_percent            0
# country3_name               0
# country3_percent            0
# country4_name               0
# country4_percent            0
# country5_name               0
# country5_percent            0
# female                      0
# male                        0
# age_18_24                   0
# age_25_34                   0
# age_35_44                   0
# age_45_54                   0
# age_55_64                   0
# age_65_plus                 0
# marketing_direct            0
# marketing_referrals         0
# marketing_organic_search    0
# marketing_paid_search       0
# ...

# %%
plt.scatter(data['ad_networks'], data['age_65_plus'])

# %%
sns.heatmap(data.corr(), annot = True )
# Out:
# <ipython-input-35-43c471618308>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True )
# <Axes: >

# %%
plt.figure(figsize = ( 10, 8 ))
